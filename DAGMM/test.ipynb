# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dd=pd.read_csv('/DAGMM/data/TimeSeries.csv')

# %%
chunk=len(df)//5

fig, axs = plt.subplots(5, figsize=(20, 16))
for i in range(5):
    x = list(df.index)[i * chunk: (i + 1) * chunk]
    y = list(df['label'])[i * chunk: (i + 1) * chunk]
    score = list(df['anomaly_score'])[i * chunk: (i + 1) * chunk]
    
    axs[i].scatter(x, score, c=y)
